# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
print('Numpy Version:', np.__version__)
print('Pandas Version:', pd.__version__)
print('Seaborn Version:', sns.__version__)
# Out:
# Numpy Version: 1.20.3
# Pandas Version: 1.3.4
# Seaborn Version: 0.11.2

# %%
from matplotlib import rcParams
rcParams['figure.figsize'] = 12, 4
rcParams['lines.linewidth'] = 3
rcParams['xtick.labelsize'] = 'x-large'
rcParams['ytick.labelsize'] = 'x-large'

# %%
df= pd.read_csv('/content/drive/My Drive/Investigate Hotel Business using Data Visualization/hotel_bookings_data.csv')

# %%
df = pd.read_csv('hotel_bookings_data.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 29 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_weekdays_nights        119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
#  12  meal                            119390 non-null  object
#  13  city                            118902 non-null  object
#  14  market_segment                  119390 non-null  object
#  15  distribution_channel            119390 non-null  object
#  16  is_repeated_guest               119390 non-null  int64
#  17  previous_cancellations          119390 non-null  int64
#  18  previous_bookings_not_canceled  119390 non-null  int64
#  19  booking_changes                 119390 non-null  int64
#  20  deposit_type                    119390 non-null  object
#  21  agent                           103050 non-null  float64
#  22  company                         6797 non-null    float64
#  23  days_in_waiting_list            119390 non-null  int64
#  24  customer_type                   119390 non-null  object
#  25  adr                             119390 non-null  float64
#  26  required_car_parking_spaces     119390 non-null  int64
#  27  total_of_special_requests       119390 non-null  int64
#  28  reservation_status              119390 non-null  object
# dtypes: float64(4), int64(16), object(9)
# memory usage: 26.4+ MB

# %%
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2017          September
# 1  Resort Hotel            0        737               2017          September
# 2  Resort Hotel            0          7               2017          September
# 3  Resort Hotel            0         13               2017          September
# 4  Resort Hotel            0         14               2017          September
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_weekdays_nights  adults  ...  \
# 0                        0                         0       2  ...
# 1                        0                         0       2  ...
# 2                        0                         1       1  ...
# 3                        0                         1       1  ...
# 4                        0                         2       2  ...
#
#    booking_changes  deposit_type  agent company days_in_waiting_list  \
# 0                3    No Deposit    NaN     NaN                    0
# 1                4    No Deposit    NaN     NaN                    0
# 2                0    No Deposit    NaN     NaN                    0
# 3                0    No Deposit  304.0     NaN                    0
# 4                0    No Deposit  240.0     NaN                    0
#
#   customer_type   adr  required_car_parking_spaces  total_of_special_requests  \
# 0      Personal   0.0                            0                          0
# 1      Personal   0.0                            0                          0
# 2      Personal  75.0                            0                          0
# 3      Personal  75.0                            0                          0
# 4      Personal  98.0                            0                          1
#
#    reservation_status
# 0           Check-Out
# 1           Check-Out
# 2           Check-Out
# 3           Check-Out
# 4           Check-Out
#
# [5 rows x 29 columns]

# %%
print('Data duplicate pada dataset ini ada',df.duplicated().sum())
# Out:
# Data duplicate pada dataset ini ada 33261

# %%
df1=df.drop_duplicates()

# %%
df1.duplicated().sum()
# Out:
# 0

# %%
df1.isna().sum()
# Out:
# hotel                                 0
# is_canceled                           0
# lead_time                             0
# arrival_date_year                     0
# arrival_date_month                    0
# arrival_date_week_number              0
# arrival_date_day_of_month             0
# stays_in_weekend_nights               0
# stays_in_weekdays_nights              0
# adults                                0
# children                              4
# babies                                0
# meal                                  0
# city                                450
# market_segment                        0
# distribution_channel                  0
# is_repeated_guest                     0
# previous_cancellations                0
# previous_bookings_not_canceled        0
# booking_changes                       0
# deposit_type                          0
# agent                             11941
# company                           81019
# days_in_waiting_list                  0
# customer_type                         0
# adr                                   0
# required_car_parking_spaces           0
# total_of_special_requests             0
# reservation_status                    0
# dtype: int64

# %%
df1['children']=df1['children'].fillna(0)
df1['city']=df1['city'].fillna('unknown')
df1['agent']=df1['agent'].fillna(0)
df1['company']=df1['company'].fillna(0)

# %%
df1.duplicated().sum()
# Out:
# 0

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 86129 entries, 0 to 119389
# Data columns (total 29 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   hotel                           86129 non-null  object
#  1   is_canceled                     86129 non-null  int64
#  2   lead_time                       86129 non-null  int64
#  3   arrival_date_year               86129 non-null  int64
#  4   arrival_date_month              86129 non-null  object
#  5   arrival_date_week_number        86129 non-null  int64
#  6   arrival_date_day_of_month       86129 non-null  int64
#  7   stays_in_weekend_nights         86129 non-null  int64
#  8   stays_in_weekdays_nights        86129 non-null  int64
#  9   adults                          86129 non-null  int64
#  10  children                        86129 non-null  float64
#  11  babies                          86129 non-null  int64
#  12  meal                            86129 non-null  object
#  13  city                            86129 non-null  object
#  14  market_segment                  86129 non-null  object
#  15  distribution_channel            86129 non-null  object
#  16  is_repeated_guest               86129 non-null  int64
#  17  previous_cancellations          86129 non-null  int64
#  18  previous_bookings_not_canceled  86129 non-null  int64
#  19  booking_changes                 86129 non-null  int64
#  20  deposit_type                    86129 non-null  object
#  21  agent                           86129 non-null  float64
#  22  company                         86129 non-null  float64
#  23  days_in_waiting_list            86129 non-null  int64
#  24  customer_type                   86129 non-null  object
#  25  adr                             86129 non-null  float64
#  26  required_car_parking_spaces     86129 non-null  int64
#  27  total_of_special_requests       86129 non-null  int64
#  28  reservation_status              86129 non-null  object
# dtypes: float64(4), int64(16), object(9)
# memory usage: 19.7+ MB

# %%
df1['children']=df1['children'].astype('int64')
df1['agent']=df1['agent'].astype('int64')
df1['company']=df1['company'].astype('int64')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 86129 entries, 0 to 119389
# Data columns (total 29 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   hotel                           86129 non-null  object
#  1   is_canceled                     86129 non-null  int64
#  2   lead_time                       86129 non-null  int64
#  3   arrival_date_year               86129 non-null  int64
#  4   arrival_date_month              86129 non-null  object
#  5   arrival_date_week_number        86129 non-null  int64
#  6   arrival_date_day_of_month       86129 non-null  int64
#  7   stays_in_weekend_nights         86129 non-null  int64
#  8   stays_in_weekdays_nights        86129 non-null  int64
#  9   adults                          86129 non-null  int64
#  10  children                        86129 non-null  int64
#  11  babies                          86129 non-null  int64
#  12  meal                            86129 non-null  object
#  13  city                            86129 non-null  object
#  14  market_segment                  86129 non-null  object
#  15  distribution_channel            86129 non-null  object
#  16  is_repeated_guest               86129 non-null  int64
#  17  previous_cancellations          86129 non-null  int64
#  18  previous_bookings_not_canceled  86129 non-null  int64
#  19  booking_changes                 86129 non-null  int64
#  20  deposit_type                    86129 non-null  object
#  21  agent                           86129 non-null  int64
#  22  company                         86129 non-null  int64
#  23  days_in_waiting_list            86129 non-null  int64
#  24  customer_type                   86129 non-null  object
#  25  adr                             86129 non-null  float64
#  26  required_car_parking_spaces     86129 non-null  int64
#  27  total_of_special_requests       86129 non-null  int64
#  28  reservation_status              86129 non-null  object
# dtypes: float64(1), int64(19), object(9)
# memory usage: 19.7+ MB

# %%
df1['meal'].unique()
# Out:
# array(['Breakfast', 'Full Board', 'Dinner', 'No Meal', 'Undefined'],
#       dtype=object)

# %%
df1['meal']=df1['meal'].replace(['Undefined'],'No Meal')

# %%
df1['meal'].value_counts()
# Out:
# Breakfast     67088
# No Meal        9896
# Dinner         8798
# Full Board      347
# Name: meal, dtype: int64

# %%
df1['total_guest']=df1['adults']+df1['children']+df1['babies']

# %%
df1['no_night']=df1['stays_in_weekend_nights']+df1['stays_in_weekdays_nights']

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 86129 entries, 0 to 119389
# Data columns (total 31 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   hotel                           86129 non-null  object
#  1   is_canceled                     86129 non-null  int64
#  2   lead_time                       86129 non-null  int64
#  3   arrival_date_year               86129 non-null  int64
#  4   arrival_date_month              86129 non-null  object
#  5   arrival_date_week_number        86129 non-null  int64
#  6   arrival_date_day_of_month       86129 non-null  int64
#  7   stays_in_weekend_nights         86129 non-null  int64
#  8   stays_in_weekdays_nights        86129 non-null  int64
#  9   adults                          86129 non-null  int64
#  10  children                        86129 non-null  int64
#  11  babies                          86129 non-null  int64
#  12  meal                            86129 non-null  object
#  13  city                            86129 non-null  object
#  14  market_segment                  86129 non-null  object
#  15  distribution_channel            86129 non-null  object
#  16  is_repeated_guest               86129 non-null  int64
#  17  previous_cancellations          86129 non-null  int64
#  18  previous_bookings_not_canceled  86129 non-null  int64
#  19  booking_changes                 86129 non-null  int64
#  20  deposit_type                    86129 non-null  object
#  21  agent                           86129 non-null  int64
#  22  company                         86129 non-null  int64
#  23  days_in_waiting_list            86129 non-null  int64
#  24  customer_type                   86129 non-null  object
#  25  adr                             86129 non-null  float64
#  26  required_car_parking_spaces     86129 non-null  int64
#  27  total_of_special_requests       86129 non-null  int64
#  28  reservation_status              86129 non-null  object
#  29  total_guest                     86129 non-null  int64
#  30  no_night                        86129 non-null  int64
# dtypes: float64(1), int64(21), object(9)
# memory usage: 21.0+ MB

# %%
df3 = df1[(df1['total_guest'] > 0) & (df1['no_night'] > 0)]

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 85378 entries, 2 to 119389
# Data columns (total 31 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   hotel                           85378 non-null  object
#  1   is_canceled                     85378 non-null  int64
#  2   lead_time                       85378 non-null  int64
#  3   arrival_date_year               85378 non-null  int64
#  4   arrival_date_month              85378 non-null  object
#  5   arrival_date_week_number        85378 non-null  int64
#  6   arrival_date_day_of_month       85378 non-null  int64
#  7   stays_in_weekend_nights         85378 non-null  int64
#  8   stays_in_weekdays_nights        85378 non-null  int64
#  9   adults                          85378 non-null  int64
#  10  children                        85378 non-null  int64
#  11  babies                          85378 non-null  int64
#  12  meal                            85378 non-null  object
#  13  city                            85378 non-null  object
#  14  market_segment                  85378 non-null  object
#  15  distribution_channel            85378 non-null  object
#  16  is_repeated_guest               85378 non-null  int64
#  17  previous_cancellations          85378 non-null  int64
#  18  previous_bookings_not_canceled  85378 non-null  int64
#  19  booking_changes                 85378 non-null  int64
#  20  deposit_type                    85378 non-null  object
#  21  agent                           85378 non-null  int64
#  22  company                         85378 non-null  int64
#  23  days_in_waiting_list            85378 non-null  int64
#  24  customer_type                   85378 non-null  object
#  25  adr                             85378 non-null  float64
#  26  required_car_parking_spaces     85378 non-null  int64
#  27  total_of_special_requests       85378 non-null  int64
#  28  reservation_status              85378 non-null  object
#  29  total_guest                     85378 non-null  int64
#  30  no_night                        85378 non-null  int64
# dtypes: float64(1), int64(21), object(9)
# memory usage: 20.8+ MB

# %%
df3.to_csv('hotel_bookings_datanew.csv', index=False)

# %%
df3_jp=df3.groupby(['arrival_date_month','hotel'])['arrival_date_year'].agg(['nunique','count']).reset_index()
df3_jp.columns=['month','hotel_name','yearunique','total_book']
df3_jp
# Out:
#         month    hotel_name  yearunique  total_book
# 0       April    City Hotel           2        3514
# 1       April  Resort Hotel           2        2453
# 2      August    City Hotel           2        4908
# 3      August  Resort Hotel           2        2705
# 4    December    City Hotel           2        4009
# 5    December  Resort Hotel           2        2618
# 6    February    City Hotel           2        2952
# 7    February  Resort Hotel           2        2044
# 8     January    City Hotel           2        2849
# 9     January  Resort Hotel           2        1995
# 10       July    City Hotel           2        5321
# 11       July  Resort Hotel           2        2863
# 12       June    City Hotel           2        5017
# 13       June  Resort Hotel           2        2756
# 14      March    City Hotel           2        2674
# 15      March  Resort Hotel           2        1904
# 16        May    City Hotel           2        4777
# 17        May  Resort Hotel           2        2585
# 18   November    City Hotel           2        4040
# 19   November  Resort Hotel           2        2386
# 20    October    City Hotel           3        6473
# 21    October  Resort Hotel           3        4615
# 22  September    City Hotel           3        5657
# 23  September  Resort Hotel           3        4263

# %% [markdown]
# Pada bulan oktober dan september, data yang diambil 3 tahun yang lalu sedangkan sisanya diambil 2 bulan yang lalu. maka dari itu, data ini perlu untuk di normalisasikan lagi.

# %%
df3_jp['average_book']=round(df3_jp['total_book']/df3_jp['yearunique'])
df3_jp
# Out:
#         month    hotel_name  yearunique  total_book  average_book
# 0       April    City Hotel           2        3514        1757.0
# 1       April  Resort Hotel           2        2453        1226.0
# 2      August    City Hotel           2        4908        2454.0
# 3      August  Resort Hotel           2        2705        1352.0
# 4    December    City Hotel           2        4009        2004.0
# 5    December  Resort Hotel           2        2618        1309.0
# 6    February    City Hotel           2        2952        1476.0
# 7    February  Resort Hotel           2        2044        1022.0
# 8     January    City Hotel           2        2849        1424.0
# 9     January  Resort Hotel           2        1995         998.0
# 10       July    City Hotel           2        5321        2660.0
# 11       July  Resort Hotel           2        2863        1432.0
# 12       June    City Hotel           2        5017        2508.0
# 13       June  Resort Hotel           2        2756        1378.0
# 14      March    City Hotel           2        2674        1337.0
# 15      March  Resort Hotel           2        1904         952.0
# 16        May    City Hotel           2        4777        2388.0
# 17        May  Resort Hotel           2        2585        1292.0
# 18   November    City Hotel           2        4040        2020.0
# 19   November  Resort Hotel           2        2386        1193.0
# 20    October    City Hotel           3        6473        2158.0
# 21    October  Resort Hotel           3        4615        1538.0
# 22  September    City Hotel           3        5657        1886.0
# 23  September  Resort Hotel           3        4263        1421.0

# %%
order_months=['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec']
df3_jp['months']=df3_jp['month'].str[:3]
df3_jp['months']= pd.Categorical(df3_jp['months'],categories=order_months,ordered=True) 
df3_jp
# Out:
#         month    hotel_name  yearunique  total_book  average_book months
# 0       April    City Hotel           2        3514        1757.0    Apr
# 1       April  Resort Hotel           2        2453        1226.0    Apr
# 2      August    City Hotel           2        4908        2454.0    Aug
# 3      August  Resort Hotel           2        2705        1352.0    Aug
# 4    December    City Hotel           2        4009        2004.0    Dec
# 5    December  Resort Hotel           2        2618        1309.0    Dec
# 6    February    City Hotel           2        2952        1476.0    Feb
# 7    February  Resort Hotel           2        2044        1022.0    Feb
# 8     January    City Hotel           2        2849        1424.0    Jan
# 9     January  Resort Hotel           2        1995         998.0    Jan
# 10       July    City Hotel           2        5321        2660.0    Jul
# 11       July  Resort Hotel           2        2863        1432.0    Jul
# 12       June    City Hotel           2        5017        2508.0    Jun
# 13       June  Resort Hotel           2        2756        1378.0    Jun
# 14      March    City Hotel           2        2674        1337.0    Mar
# 15      March  Resort Hotel           2        1904         952.0    Mar
# 16        May    City Hotel           2        4777        2388.0    May
# 17        May  Resort Hotel           2        2585        1292.0    May
# 18   November    City Hotel           2        4040        2020.0    Nov
# 19   November  Resort Hotel           2        2386        1193.0    Nov
# 20    October    City Hotel           3        6473        2158.0    Oct
# 21    October  Resort Hotel           3        4615        1538.0    Oct
# 22  September    City Hotel           3        5657        1886.0    Sep
# 23  September  Resort Hotel           3        4263        1421.0    Sep

# %%
plt.figure(figsize=(15,10))
sns.lineplot(x='months', y='average_book', hue='hotel_name',size='hotel_name', sizes=(5,5), data= df3_jp, palette=['purple','green'])

plt.xlabel('Arrival Month', fontsize=16)
plt.ylabel('Average Number of Booking', fontsize=16)

plt.title('Average number of Booking in City Hotel and Resort Hotel', fontsize=25)

plt.axvline(4, linestyle='-', color='blue')
plt.axvline(6, linestyle='-', color='blue')
plt.stackplot(np.arange(4,7,1),[[5000]], color='lightblue', alpha=0.5)
plt.text(x=4.7, y=4400, s='Holiday\nSeason', fontsize=16, color='red')

plt.axvline(9, linestyle='-', color='blue')
plt.axvline(11, linestyle='-', color='blue')
plt.stackplot(np.arange(9,12,1),[[5000]], color='lightblue', alpha=0.5)
plt.text(x=9.7, y=4400, s='Holiday\nSeason', fontsize=16, color='red')

plt.tight_layout()

plt.savefig('average number.jpeg',dpi=200)

# %%
df4=df3.copy()

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 85378 entries, 2 to 119389
# Data columns (total 31 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   hotel                           85378 non-null  object
#  1   is_canceled                     85378 non-null  int64
#  2   lead_time                       85378 non-null  int64
#  3   arrival_date_year               85378 non-null  int64
#  4   arrival_date_month              85378 non-null  object
#  5   arrival_date_week_number        85378 non-null  int64
#  6   arrival_date_day_of_month       85378 non-null  int64
#  7   stays_in_weekend_nights         85378 non-null  int64
#  8   stays_in_weekdays_nights        85378 non-null  int64
#  9   adults                          85378 non-null  int64
#  10  children                        85378 non-null  int64
#  11  babies                          85378 non-null  int64
#  12  meal                            85378 non-null  object
#  13  city                            85378 non-null  object
#  14  market_segment                  85378 non-null  object
#  15  distribution_channel            85378 non-null  object
#  16  is_repeated_guest               85378 non-null  int64
#  17  previous_cancellations          85378 non-null  int64
#  18  previous_bookings_not_canceled  85378 non-null  int64
#  19  booking_changes                 85378 non-null  int64
#  20  deposit_type                    85378 non-null  object
#  21  agent                           85378 non-null  int64
#  22  company                         85378 non-null  int64
#  23  days_in_waiting_list            85378 non-null  int64
#  24  customer_type                   85378 non-null  object
#  25  adr                             85378 non-null  float64
#  26  required_car_parking_spaces     85378 non-null  int64
#  27  total_of_special_requests       85378 non-null  int64
#  28  reservation_status              85378 non-null  object
#  29  total_guest                     85378 non-null  int64
#  30  no_night                        85378 non-null  int64
# dtypes: float64(1), int64(21), object(9)
# memory usage: 20.8+ MB

# %%
df4['no_night'].unique()
# Out:
# array([ 1,  2,  3,  4,  5,  6,  7, 14, 15, 10, 11,  8,  9, 21, 13, 12, 18,
#        46, 28, 17, 19, 22, 23, 16, 29, 42, 20, 26, 33, 30, 56, 25, 27, 60,
#        69, 35, 45, 38, 24, 48, 34], dtype=int64)

# %%
df4['no_night'].value_counts()
# Out:
# 3     17527
# 1     16908
# 2     15332
# 4     13382
# 7      7464
# 5      6698
# 6      3249
# 10     1071
# 8      1059
# 14      857
# 9       778
# 11      366
# 12      196
# 13      132
# 15       69
# 21       55
# 28       34
# 16       33
# 19       22
# 18       22
# 17       20
# 25       14
# 29       13
# 20       13
# 22       12
# 30       11
# 26        6
# 24        6
# 23        5
# 35        5
# 27        4
# 42        4
# 56        2
# 33        2
# 60        1
# 69        1
# 46        1
# 45        1
# 38        1
# 48        1
# 34        1
# Name: no_night, dtype: int64

# %%
df4['total_duration']=np.where(df4['no_night']>21,21,
                               np.where(df4['no_night']>14,15, df3['no_night']))

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 85378 entries, 2 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   hotel                           85378 non-null  object
#  1   is_canceled                     85378 non-null  int64
#  2   lead_time                       85378 non-null  int64
#  3   arrival_date_year               85378 non-null  int64
#  4   arrival_date_month              85378 non-null  object
#  5   arrival_date_week_number        85378 non-null  int64
#  6   arrival_date_day_of_month       85378 non-null  int64
#  7   stays_in_weekend_nights         85378 non-null  int64
#  8   stays_in_weekdays_nights        85378 non-null  int64
#  9   adults                          85378 non-null  int64
#  10  children                        85378 non-null  int64
#  11  babies                          85378 non-null  int64
#  12  meal                            85378 non-null  object
#  13  city                            85378 non-null  object
#  14  market_segment                  85378 non-null  object
#  15  distribution_channel            85378 non-null  object
#  16  is_repeated_guest               85378 non-null  int64
#  17  previous_cancellations          85378 non-null  int64
#  18  previous_bookings_not_canceled  85378 non-null  int64
#  19  booking_changes                 85378 non-null  int64
#  20  deposit_type                    85378 non-null  object
#  21  agent                           85378 non-null  int64
#  22  company                         85378 non-null  int64
#  23  days_in_waiting_list            85378 non-null  int64
#  24  customer_type                   85378 non-null  object
#  25  adr                             85378 non-null  float64
#  26  required_car_parking_spaces     85378 non-null  int64
#  27  total_of_special_requests       85378 non-null  int64
#  28  reservation_status              85378 non-null  object
#  29  total_guest                     85378 non-null  int64
#  30  no_night                        85378 non-null  int64
#  31  total_duration                  85378 non-null  int64
# dtypes: float64(1), int64(22), object(9)
# memory usage: 21.5+ MB

# %%
df4['total_duration'].value_counts()
# Out:
# 3     17527
# 1     16908
# 2     15332
# 4     13382
# 7      7464
# 5      6698
# 6      3249
# 10     1071
# 8      1059
# 14      857
# 9       778
# 11      366
# 15      234
# 12      196
# 13      132
# 21      125
# Name: total_duration, dtype: int64

# %%
df4_ph=df4.groupby(['hotel','total_duration','is_canceled']).agg({'arrival_date_month':'count'}).reset_index()

df4_ph
# Out:
#            hotel  total_duration  is_canceled  arrival_date_month
# 0     City Hotel               1            0                7841
# 1     City Hotel               1            1                2259
# 2     City Hotel               2            0                7374
# 3     City Hotel               2            1                3133
# 4     City Hotel               3            0                9136
# ..           ...             ...          ...                 ...
# 59  Resort Hotel              14            1                 159
# 60  Resort Hotel              15            0                  87
# 61  Resort Hotel              15            1                  47
# 62  Resort Hotel              21            0                  54
# 63  Resort Hotel              21            1                  26
#
# [64 rows x 4 columns]

# %%
df4_pivot=pd.pivot_table(df4_ph, values='arrival_date_month',index=['hotel','total_duration'], columns='is_canceled').reset_index()
df4_pivot.columns=['hotel_name','total_nights','not_canceld','cancelled']
df4_pivot
# Out:
#       hotel_name  total_nights  not_canceld  cancelled
# 0     City Hotel             1         7841       2259
# 1     City Hotel             2         7374       3133
# 2     City Hotel             3         9136       4182
# 3     City Hotel             4         6440       3059
# 4     City Hotel             5         2887       1257
# 5     City Hotel             6         1022        610
# 6     City Hotel             7         1145        692
# 7     City Hotel             8          195        166
# 8     City Hotel             9          111         87
# 9     City Hotel            10           78        110
# 10    City Hotel            11           31         45
# 11    City Hotel            12           30         28
# 12    City Hotel            13           15         25
# 13    City Hotel            14           26         62
# 14    City Hotel            15           27         73
# 15    City Hotel            21            6         39
# 16  Resort Hotel             1         5955        853
# 17  Resort Hotel             2         3829        996
# 18  Resort Hotel             3         3127       1082
# 19  Resort Hotel             4         2839       1044
# 20  Resort Hotel             5         1774        780
# 21  Resort Hotel             6         1107        510
# 22  Resort Hotel             7         4034       1593
# 23  Resort Hotel             8          466        232
# 24  Resort Hotel             9          394        186
# 25  Resort Hotel            10          657        226
# 26  Resort Hotel            11          227         63
# 27  Resort Hotel            12           89         49
# 28  Resort Hotel            13           68         24
# 29  Resort Hotel            14          610        159
# 30  Resort Hotel            15           87         47
# 31  Resort Hotel            21           54         26

# %%
df4_pivot['percent_canceled'] = round(df4_pivot['cancelled']*100.0/(df4_pivot['not_canceld']+df4_pivot['cancelled']),2)

# %%
df4_pivot
# Out:
#       hotel_name  total_nights  not_canceld  cancelled  percent_canceled
# 0     City Hotel             1         7841       2259             22.37
# 1     City Hotel             2         7374       3133             29.82
# 2     City Hotel             3         9136       4182             31.40
# 3     City Hotel             4         6440       3059             32.20
# 4     City Hotel             5         2887       1257             30.33
# 5     City Hotel             6         1022        610             37.38
# 6     City Hotel             7         1145        692             37.67
# 7     City Hotel             8          195        166             45.98
# 8     City Hotel             9          111         87             43.94
# 9     City Hotel            10           78        110             58.51
# 10    City Hotel            11           31         45             59.21
# 11    City Hotel            12           30         28             48.28
# 12    City Hotel            13           15         25             62.50
# 13    City Hotel            14           26         62             70.45
# 14    City Hotel            15           27         73             73.00
# 15    City Hotel            21            6         39             86.67
# 16  Resort Hotel             1         5955        853             12.53
# 17  Resort Hotel             2         3829        996             20.64
# 18  Resort Hotel             3         3127       1082             25.71
# 19  Resort Hotel             4         2839       1044             26.89
# 20  Resort Hotel             5         1774        780             30.54
# 21  Resort Hotel             6         1107        510             31.54
# 22  Resort Hotel             7         4034       1593             28.31
# 23  Resort Hotel             8          466        232             33.24
# 24  Resort Hotel             9          394        186             32.07
# 25  Resort Hotel            10          657        226             25.59
# 26  Resort Hotel            11          227         63             21.72
# 27  Resort Hotel            12           89         49             35.51
# 28  Resort Hotel            13           68         24             26.09
# 29  Resort Hotel            14          610        159             20.68
# 30  Resort Hotel            15           87         47             35.07
# 31  Resort Hotel            21           54         26             32.50

# %%
plt.figure(figsize=(15,10))
sns.barplot(x='total_nights', y='percent_canceled', hue='hotel_name',data= df4_pivot, palette=['brown','chocolate'])
sns.regplot(x='total_nights', y='percent_canceled', data=df4_pivot[df4_pivot['hotel_name'] == 'Resort Hotel'], scatter=False, label='Trend Resort Hotel', color='Khaki', truncate=False)
sns.regplot(x='total_nights', y='percent_canceled', data=df4_pivot[df4_pivot['hotel_name'] == 'City Hotel'], scatter=False, label='Trend City Hotel', color='coral', truncate=False)

plt.legend(title='Hotel Type :', title_fontsize=15, prop={'size':13})
plt.xlabel('Stay Duration', fontsize=16)
plt.ylabel('Percent of Canceled', fontsize=16)

plt.title('Percentage of canceled with duration in City Hotel and Resort Hotel', fontsize=25)

plt.tight_layout()

plt.savefig('percent canceled.jpeg',dpi=200)

# %%
df5=df4.copy()

# %%
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 85378 entries, 2 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   hotel                           85378 non-null  object
#  1   is_canceled                     85378 non-null  int64
#  2   lead_time                       85378 non-null  int64
#  3   arrival_date_year               85378 non-null  int64
#  4   arrival_date_month              85378 non-null  object
#  5   arrival_date_week_number        85378 non-null  int64
#  6   arrival_date_day_of_month       85378 non-null  int64
#  7   stays_in_weekend_nights         85378 non-null  int64
#  8   stays_in_weekdays_nights        85378 non-null  int64
#  9   adults                          85378 non-null  int64
#  10  children                        85378 non-null  int64
#  11  babies                          85378 non-null  int64
#  12  meal                            85378 non-null  object
#  13  city                            85378 non-null  object
#  14  market_segment                  85378 non-null  object
#  15  distribution_channel            85378 non-null  object
#  16  is_repeated_guest               85378 non-null  int64
#  17  previous_cancellations          85378 non-null  int64
#  18  previous_bookings_not_canceled  85378 non-null  int64
#  19  booking_changes                 85378 non-null  int64
#  20  deposit_type                    85378 non-null  object
#  21  agent                           85378 non-null  int64
#  22  company                         85378 non-null  int64
#  23  days_in_waiting_list            85378 non-null  int64
#  24  customer_type                   85378 non-null  object
#  25  adr                             85378 non-null  float64
#  26  required_car_parking_spaces     85378 non-null  int64
#  27  total_of_special_requests       85378 non-null  int64
#  28  reservation_status              85378 non-null  object
#  29  total_guest                     85378 non-null  int64
#  30  no_night                        85378 non-null  int64
#  31  total_duration                  85378 non-null  int64
# dtypes: float64(1), int64(22), object(9)
# memory usage: 21.5+ MB

# %%
df5['lead_time'].unique()
# Out:
# array([  7,  13,  14,   0,   9,  85,  75,  23,  35,  68,  18,  37,  12,
#         72, 127,  78,  48,  60,  77,  99, 118,  95,  96,  69,  45,  40,
#         15,  36,  43,  70,  16, 107,  47, 113,  90,  50,  93,  76,   3,
#          1,  10,   5,  17,  51,  71,  63,  62, 101,   2,  81, 368, 364,
#        324,  79,  21, 109, 102,   4,  98,  92,  26,  73, 115,  86,  52,
#         29,  30,  33,  32,   8, 100,  44,  80,  97,  64,  39,  34,  27,
#         82,  94, 110, 111,  84,  66, 104,  28, 258, 112,  65,  67,  55,
#         88,  54, 292,  83, 105, 280, 394,  24, 103, 366, 249,  22,  91,
#         11, 108, 106,  31,  87,  41, 304, 117,  59,  53,  58, 116,  42,
#        321,  38,  56,  49, 317,   6,  57,  19,  25, 315, 123,  46,  89,
#         61, 312, 299, 130,  74, 298, 119,  20, 286, 136, 129, 124, 327,
#        131, 460, 140, 114, 139, 122, 137, 126, 120, 128, 135, 150, 143,
#        151, 132, 125, 157, 147, 138, 156, 164, 346, 159, 160, 161, 333,
#        381, 149, 154, 297, 163, 314, 155, 323, 340, 356, 142, 328, 144,
#        336, 248, 302, 175, 344, 382, 146, 170, 166, 338, 167, 310, 148,
#        165, 172, 171, 145, 121, 178, 305, 173, 152, 354, 347, 158, 185,
#        349, 183, 352, 177, 200, 192, 361, 207, 174, 330, 134, 350, 334,
#        283, 197, 133, 153, 241, 193, 235, 194, 261, 260, 216, 169, 209,
#        238, 215, 141, 189, 187, 223, 284, 214, 202, 211, 168, 230, 203,
#        188, 232, 709, 219, 162, 196, 190, 259, 228, 176, 250, 201, 186,
#        199, 180, 206, 205, 224, 222, 275, 212, 229, 218, 208, 191, 181,
#        179, 246, 255, 226, 288, 253, 262, 236, 256, 234, 254, 468, 213,
#        237, 198, 195, 239, 263, 265, 274, 217, 210, 220, 307, 221, 233,
#        257, 227, 276, 225, 264, 311, 277, 204, 290, 266, 182, 270, 294,
#        319, 252, 282, 251, 322, 291, 269, 240, 271, 184, 231, 268, 247,
#        273, 300, 301, 267, 244, 306, 293, 309, 272, 242, 295, 285, 243,
#        308, 398, 303, 245, 424, 279, 331, 281, 339, 434, 357, 325, 329,
#        278, 332, 343, 345, 360, 348, 367, 353, 373, 374, 406, 400, 326,
#        379, 399, 316, 341, 320, 385, 355, 363, 358, 296, 422, 390, 335,
#        370, 376, 342, 375, 397, 289, 542, 403, 383, 384, 359, 393, 337,
#        362, 365, 435, 386, 378, 313, 351, 287, 471, 462, 411, 450, 318,
#        372, 371, 454, 532, 445, 388, 407, 443, 437, 451, 391, 405, 412,
#        419, 420, 426, 433, 440, 429, 418, 447, 461, 605, 457, 475, 464,
#        482, 626, 489, 496, 503, 510, 517, 524, 531, 538, 545, 552, 559,
#        566, 573, 580, 587, 594, 601, 608, 615, 622, 629, 396, 410, 395,
#        423, 408, 409, 448, 465, 387, 414, 476, 479, 467, 490, 493, 389,
#        478, 504, 507, 458, 518, 521, 377, 444, 380, 463], dtype=int64)

# %%
df5['lead_time'].value_counts()
# Out:
# 0      5633
# 1      3130
# 2      1891
# 3      1683
# 4      1538
#        ...
# 410       1
# 605       1
# 400       1
# 626       1
# 463       1
# Name: lead_time, Length: 478, dtype: int64

# %%
df5['lead_time'].max()
# Out:
# 709

# %%
df5['lead_time'].min()
# Out:
# 0

# %%
df5['lead_time'].describe()
# Out:
# count    85378.000000
# mean        79.647567
# std         85.517499
# min          0.000000
# 25%         11.000000
# 50%         49.000000
# 75%        125.000000
# max        709.000000
# Name: lead_time, dtype: float64

# %%
df5['total_lead_time']=np.where(df5['lead_time']>400,401,df4['lead_time'])
df5['total_lead_time'].value_counts()
# Out:
# 0      5633
# 1      3130
# 2      1891
# 3      1683
# 4      1538
#        ...
# 400       1
# 370       1
# 387       1
# 389       1
# 380       1
# Name: total_lead_time, Length: 400, dtype: int64

# %%
df5['total_lead_time'].describe()
# Out:
# count    85378.000000
# mean        79.396636
# std         84.404118
# min          0.000000
# 25%         11.000000
# 50%         49.000000
# 75%        125.000000
# max        401.000000
# Name: total_lead_time, dtype: float64

# %%
lt=list(np.arange(0,max(df5['total_lead_time'])+30,30))
print(lt)
# Out:
# [0, 30, 60, 90, 120, 150, 180, 210, 240, 270, 300, 330, 360, 390, 420]

# %%
lt_labels=["{0}-{1}".format(str(lt[x]), str(lt[x+1])) for x in range(len(lt[:-1]))]
print(lt_labels)
# Out:
# ['0-30', '30-60', '60-90', '90-120', '120-150', '150-180', '180-210', '210-240', '240-270', '270-300', '300-330', '330-360', '360-390', '390-420']

# %%
df5['lead_timenew']=pd.cut(x=df5['total_lead_time'], bins=lt, labels=lt_labels, include_lowest=True, ordered=True)
df5['lead_timenew']
# Out:
# 2            0-30
# 3            0-30
# 4            0-30
# 6            0-30
# 7            0-30
#            ...
# 119385       0-30
# 119386     90-120
# 119387      30-60
# 119388     90-120
# 119389    180-210
# Name: lead_timenew, Length: 85378, dtype: category
# Categories (14, object): ['0-30' < '30-60' < '60-90' < '90-120' ... '300-330' < '330-360' < '360-390' < '390-420']

# %%
df5
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 2       Resort Hotel            0          7               2017
# 3       Resort Hotel            0         13               2017
# 4       Resort Hotel            0         14               2017
# 6       Resort Hotel            0          0               2017
# 7       Resort Hotel            0          9               2017
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2019
# 119386    City Hotel            0        102               2019
# 119387    City Hotel            0         34               2019
# 119388    City Hotel            0        109               2019
# 119389    City Hotel            0        205               2019
#
#        arrival_date_month  arrival_date_week_number  \
# 2               September                        27
# 3               September                        27
# 4               September                        27
# 6               September                        27
# 7               September                        27
# ...                   ...                       ...
# 119385            October                        35
# 119386            October                        35
# 119387            October                        35
# 119388            October                        35
# 119389            October                        35
#
#         arrival_date_day_of_month  stays_in_weekend_nights  \
# 2                               1                        0
# 3                               1                        0
# 4                               1                        0
# 6                               1                        0
# 7                               1                        0
# ...                           ...                      ...
# 119385                         30                        2
# 119386                         31                        2
# 119387                         31                        2
# 119388                         31                        2
# 119389                         29                        2
#
#         stays_in_weekdays_nights  adults  ...  customer_type     adr  \
# 2                              1       1  ...       Personal   75.00
# 3                              1       1  ...       Personal   75.00
# 4                              2       2  ...       Personal   98.00
# 6                              2       2  ...       Personal  107.00
# 7                              2       2  ...       Personal  103.00
# ...                          ...     ...  ...            ...     ...
# 119385                         5       2  ...       Personal   96.14
# 119386                         5       3  ...       Personal  225.43
# 119387                         5       2  ...       Personal  157.71
# 119388                         5       2  ...       Personal  104.40
# 119389                         7       2  ...       Personal  151.20
#
#        required_car_parking_spaces total_of_special_requests  \
# 2                                0                         0
# 3                                0                         0
# 4                                0                         1
# 6                                0                         0
# 7                                0                         1
# ...                            ...                       ...
# 119385                           0                         0
# 119386                           0                         2
# 119387                           0                         4
# 119388                           0                         0
# 119389                           0                         2
#
#        reservation_status total_guest  no_night  total_duration  \
# 2               Check-Out           1         1               1
# 3               Check-Out           1         1               1
# 4               Check-Out           2         2               2
# 6               Check-Out           2         2               2
# 7               Check-Out           2         2               2
# ...                   ...         ...       ...             ...
# 119385          Check-Out           2         7               7
# 119386          Check-Out           3         7               7
# 119387          Check-Out           2         7               7
# 119388          Check-Out           2         7               7
# 119389          Check-Out           2         9               9
#
#         total_lead_time  lead_timenew
# 2                     7          0-30
# 3                    13          0-30
# 4                    14          0-30
# 6                     0          0-30
# 7                     9          0-30
# ...                 ...           ...
# 119385               23          0-30
# 119386              102        90-120
# 119387               34         30-60
# 119388              109        90-120
# 119389              205       180-210
#
# [85378 rows x 34 columns]

# %%
df5_jpjw=df5.groupby(['hotel','lead_timenew','is_canceled']).agg({'lead_time':'count'}).reset_index()
df5_jpjw
# Out:
#            hotel lead_timenew  is_canceled  lead_time
# 0     City Hotel         0-30            0      16024
# 1     City Hotel         0-30            1       3927
# 2     City Hotel        30-60            0       5818
# 3     City Hotel        30-60            1       2884
# 4     City Hotel        60-90            0       4069
# 5     City Hotel        60-90            1       2088
# 6     City Hotel       90-120            0       3031
# 7     City Hotel       90-120            1       1684
# 8     City Hotel      120-150            0       2288
# 9     City Hotel      120-150            1       1312
# 10    City Hotel      150-180            0       1851
# 11    City Hotel      150-180            1       1170
# 12    City Hotel      180-210            0       1263
# 13    City Hotel      180-210            1        837
# 14    City Hotel      210-240            0        815
# 15    City Hotel      210-240            1        568
# 16    City Hotel      240-270            0        439
# 17    City Hotel      240-270            1        414
# 18    City Hotel      270-300            0        307
# 19    City Hotel      270-300            1        327
# 20    City Hotel      300-330            0        200
# 21    City Hotel      300-330            1        260
# 22    City Hotel      330-360            0         87
# 23    City Hotel      330-360            1        157
# 24    City Hotel      360-390            0         21
# 25    City Hotel      360-390            1         39
# 26    City Hotel      390-420            0        151
# 27    City Hotel      390-420            1        160
# 28  Resort Hotel         0-30            0      12169
# 29  Resort Hotel         0-30            1       1690
# 30  Resort Hotel        30-60            0       3097
# 31  Resort Hotel        30-60            1       1292
# 32  Resort Hotel        60-90            0       2109
# 33  Resort Hotel        60-90            1        928
# 34  Resort Hotel       90-120            0       1581
# 35  Resort Hotel       90-120            1        798
# 36  Resort Hotel      120-150            0       1355
# 37  Resort Hotel      120-150            1        686
# 38  Resort Hotel      150-180            0       1524
# 39  Resort Hotel      150-180            1        639
# 40  Resort Hotel      180-210            0       1033
# 41  Resort Hotel      180-210            1        526
# 42  Resort Hotel      210-240            0        842
# 43  Resort Hotel      210-240            1        400
# 44  Resort Hotel      240-270            0        521
# 45  Resort Hotel      240-270            1        315
# 46  Resort Hotel      270-300            0        401
# 47  Resort Hotel      270-300            1        183
# 48  Resort Hotel      300-330            0        274
# 49  Resort Hotel      300-330            1        222
# 50  Resort Hotel      330-360            0        210
# 51  Resort Hotel      330-360            1        148
# 52  Resort Hotel      360-390            0        154
# 53  Resort Hotel      360-390            1         25
# 54  Resort Hotel      390-420            0         47
# 55  Resort Hotel      390-420            1         18

# %%
df5_pivot=pd.pivot_table(df5_jpjw, values='lead_time',index=['hotel','lead_timenew'], columns='is_canceled').reset_index()
df5_pivot.columns=['hotel_name','lead_timenew','not_canceled','canceled']
df5_pivot
# Out:
#       hotel_name lead_timenew  not_canceled  canceled
# 0     City Hotel         0-30         16024      3927
# 1     City Hotel        30-60          5818      2884
# 2     City Hotel        60-90          4069      2088
# 3     City Hotel       90-120          3031      1684
# 4     City Hotel      120-150          2288      1312
# 5     City Hotel      150-180          1851      1170
# 6     City Hotel      180-210          1263       837
# 7     City Hotel      210-240           815       568
# 8     City Hotel      240-270           439       414
# 9     City Hotel      270-300           307       327
# 10    City Hotel      300-330           200       260
# 11    City Hotel      330-360            87       157
# 12    City Hotel      360-390            21        39
# 13    City Hotel      390-420           151       160
# 14  Resort Hotel         0-30         12169      1690
# 15  Resort Hotel        30-60          3097      1292
# 16  Resort Hotel        60-90          2109       928
# 17  Resort Hotel       90-120          1581       798
# 18  Resort Hotel      120-150          1355       686
# 19  Resort Hotel      150-180          1524       639
# 20  Resort Hotel      180-210          1033       526
# 21  Resort Hotel      210-240           842       400
# 22  Resort Hotel      240-270           521       315
# 23  Resort Hotel      270-300           401       183
# 24  Resort Hotel      300-330           274       222
# 25  Resort Hotel      330-360           210       148
# 26  Resort Hotel      360-390           154        25
# 27  Resort Hotel      390-420            47        18

# %%
df5_pivot['prg_canceled'] = round(df5_pivot['canceled']*100.0/(df5_pivot['not_canceled']+df5_pivot['canceled']),2)
df5_pivot
# Out:
#       hotel_name lead_timenew  not_canceled  canceled  prg_canceled
# 0     City Hotel         0-30         16024      3927         19.68
# 1     City Hotel        30-60          5818      2884         33.14
# 2     City Hotel        60-90          4069      2088         33.91
# 3     City Hotel       90-120          3031      1684         35.72
# 4     City Hotel      120-150          2288      1312         36.44
# 5     City Hotel      150-180          1851      1170         38.73
# 6     City Hotel      180-210          1263       837         39.86
# 7     City Hotel      210-240           815       568         41.07
# 8     City Hotel      240-270           439       414         48.53
# 9     City Hotel      270-300           307       327         51.58
# 10    City Hotel      300-330           200       260         56.52
# 11    City Hotel      330-360            87       157         64.34
# 12    City Hotel      360-390            21        39         65.00
# 13    City Hotel      390-420           151       160         51.45
# 14  Resort Hotel         0-30         12169      1690         12.19
# 15  Resort Hotel        30-60          3097      1292         29.44
# 16  Resort Hotel        60-90          2109       928         30.56
# 17  Resort Hotel       90-120          1581       798         33.54
# 18  Resort Hotel      120-150          1355       686         33.61
# 19  Resort Hotel      150-180          1524       639         29.54
# 20  Resort Hotel      180-210          1033       526         33.74
# 21  Resort Hotel      210-240           842       400         32.21
# 22  Resort Hotel      240-270           521       315         37.68
# 23  Resort Hotel      270-300           401       183         31.34
# 24  Resort Hotel      300-330           274       222         44.76
# 25  Resort Hotel      330-360           210       148         41.34
# 26  Resort Hotel      360-390           154        25         13.97
# 27  Resort Hotel      390-420            47        18         27.69

# %%
plt.figure(figsize=(15,10))
sns.barplot(x='lead_timenew', y='prg_canceled', hue='hotel_name',data= df5_pivot, palette=['lime','green'])

plt.axvline(0.5, linestyle='-.', color='brown')
plt.text(x=-0.5, y=65, s='1 month', fontsize=16, color='black')

plt.axvline(10.5, linestyle='-.', color='brown')
plt.axvline(12.5, linestyle='-.', color='brown')
plt.text(x=10.8, y=65, s='11-12 months', fontsize=16, color='black')

plt.legend(title='Hotel Type :', title_fontsize=15, prop={'size':13})
plt.xlabel('Lead Time Duration', fontsize=16)
plt.ylabel('Percent of Canceled', fontsize=16)

plt.title('Percentage of canceled with Lead Time duration in City Hotel and Resort Hotel', fontsize=25)

plt.tight_layout()

plt.savefig('lead time.jpeg',dpi=200)
